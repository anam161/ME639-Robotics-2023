# %%
import matplotlib.pyplot as plt

# Given angles and manipulability index points
theta = [0,18,36,54,72,90,108,126,144,162]  # Example angles in degrees
MI = [0.8124877203019847, 0.8067190281005598, 0.7956483341213308, 0.7884692115474602,
    0.7794058763828958, 0.7496827365339401, 0.6932828005266608, 0.6221505652236619,
    0.5515063113434185, 0.49737143401439265]  # Example manipulability index values

# Plotting the points
plt.plot(theta, MI, marker='o', linestyle='-')
plt.xlabel('Angle (degrees)')
plt.ylabel('MI')
plt.title('MI vs Theta')
plt.grid(True)
plt.show()
